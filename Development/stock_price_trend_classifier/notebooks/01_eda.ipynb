# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")

# %%
df = pd.read_csv("../data/raw/AAPL.csv", index_col=0)
df["Close"] = pd.to_numeric(df["Close"], errors="coerce")

df.head(7)
# Out:
#                  Close                High                 Low  \
# Price
# Ticker             NaN                AAPL                AAPL
# Date               NaN                 NaN                 NaN
# 2024-01-02  183.903244  186.67705163638013  182.16961614691823
# 2024-01-03  182.526230   184.1409850600839   181.7138941984477
# 2024-01-04  180.208115  181.37706768373354  179.18775216816366
# 2024-01-05  179.484940  181.05015949262307  178.48439420396812
# 2024-01-08  183.823975  183.86360885082058  179.80196071659407
#
#                           Open    Volume
# Price
# Ticker                    AAPL      AAPL
# Date                       NaN       NaN
# 2024-01-02   185.3991117688797  82488700
# 2024-01-03  182.49651173581816  58414500
# 2024-01-04   180.4458595901839  71983600
# 2024-01-05  180.28737421180142  62379700
# 2024-01-08  180.38643729162627  59144500

# %%
df.shape
# Out:
# (513, 5)

# %%
df.info
# Out:
# <bound method DataFrame.info of                  Close                High                 Low  \
# Price
# Ticker             NaN                AAPL                AAPL
# Date               NaN                 NaN                 NaN
# 2024-01-02  183.903244  186.67705163638013  182.16961614691823
# 2024-01-03  182.526230   184.1409850600839   181.7138941984477
# 2024-01-04  180.208115  181.37706768373354  179.18775216816366
# ...                ...                 ...                 ...
# 2026-01-08  259.040009   259.2900085449219   255.6999969482422
# 2026-01-09  259.369995   260.2099914550781   256.2200012207031
# 2026-01-12  260.250000  261.29998779296875  256.79998779296875
# 2026-01-13  261.049988  261.80999755859375   258.3900146484375
# 2026-01-14  259.959991  261.82000732421875   256.7099914550781
#
#                           Open    Volume
# Price
# Ticker                    AAPL      AAPL
# Date                       NaN       NaN
# 2024-01-02   185.3991117688797  82488700
# 2024-01-03  182.49651173581816  58414500
# 2024-01-04   180.4458595901839  71983600
# ...                        ...       ...
# 2026-01-08   257.0199890136719  50419300
# 2026-01-09   259.0799865722656  39997000
# 2026-01-12   259.1600036621094  45263800
# 2026-01-13   258.7200012207031  45730800
# 2026-01-14    259.489990234375  40019400
#
# [513 rows x 5 columns]>

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                  Close                High                 Low  \
# Price
# Ticker             NaN                AAPL                AAPL
# Date               NaN                 NaN                 NaN
# 2024-01-02  183.903244  186.67705163638013  182.16961614691823
# 2024-01-03  182.526230   184.1409850600839   181.7138941984477
# 2024-01-04  180.208115  181.37706768373354  179.18775216816366
# ...                ...                 ...                 ...
# 2026-01-08  259.040009   259.2900085449219   255.6999969482422
# 2026-01-09  259.369995   260.2099914550781   256.2200012207031
# 2026-01-12  260.250000  261.29998779296875  256.79998779296875
# 2026-01-13  261.049988  261.80999755859375   258.3900146484375
# 2026-01-14  259.959991  261.82000732421875   256.7099914550781
#
#                           Open    Volume
# Price
# Ticker                    AAPL      AAPL
# Date                       NaN       NaN
# 2024-01-02   185.3991117688797  82488700
# 2024-01-03  182.49651173581816  58414500
# 2024-01-04   180.4458595901839  71983600
# ...                        ...       ...
# 2026-01-08   257.0199890136719  50419300
# 2026-01-09   259.0799865722656  39997000
# 2026-01-12   259.1600036621094  45263800
# 2026-01-13   258.7200012207031  45730800
# 2026-01-14    259.489990234375  40019400
#
# [513 rows x 5 columns]>

# %%
df = df.dropna()

# %%
df.isna()
# Out:
#             Close   High    Low   Open  Volume
# Price
# 2024-01-02  False  False  False  False   False
# 2024-01-03  False  False  False  False   False
# 2024-01-04  False  False  False  False   False
# 2024-01-05  False  False  False  False   False
# 2024-01-08  False  False  False  False   False
# ...           ...    ...    ...    ...     ...
# 2026-01-08  False  False  False  False   False
# 2026-01-09  False  False  False  False   False
# 2026-01-12  False  False  False  False   False
# 2026-01-13  False  False  False  False   False
# 2026-01-14  False  False  False  False   False
#
# [511 rows x 5 columns]

# %%
plt.figure(figsize=(12, 5))
plt.plot(df.index, df["Close"])
plt.title("AAPL Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.show()

# %%
plt.figure(figsize=(12, 4))
plt.plot(df.index, df["Volume"])
plt.title("Trading Volume Over Time")
plt.show()
